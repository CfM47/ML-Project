# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path.cwd().parents[0]
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

# Force reimport
import importlib
import notebooks.validate
importlib.reload(notebooks.validate)

from notebooks.validate import main

fig = main(
    batch_size=32,
    patience=10,
    n_folds=4,
    max_crop_size=128,
    min_crop_size=16,
    max_samples_per_image=10,
)

fig
# Out:
# Loading dataset...
# Loaded 1961 images with 3 classes
# Classes: {'Brittle': 0, 'Ductile': 1, 'Mixed': 2}
#
# ============================================================
# Training with 10% of data
# ============================================================
#
#   Fold 1/4
#     Dataset sizes - Train: 147 images -> 1470 samples (10x expansion), Val: 490 images -> 490 samples
#     Image dimensions: 500x500px, Crop range: 16-128px, Expected crop: 72px
#       Epoch   1/∞ | Train Loss: 0.9046 | Train Acc:  52.6% | Val Loss: 1.0465 | Val Acc:  43.3% | ✓ improved
